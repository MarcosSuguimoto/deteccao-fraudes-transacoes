# %% [markdown]
# <a href="https://colab.research.google.com/github/MarcosSuguimoto/deteccao-fraudes-transacoes/blob/main/deteccao_fraudes_em_transacoes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Configurando o estilo visual dos gráficos
sns.set_theme(style="whitegrid")
features_analise = ["V14", "V17", "Amount_log"]

# 1: BOXPLOTS COMPARATIVOS

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 5))
fig.suptitle(
    "Sugestão 1: Boxplots - Identificando Diferenças de Distribuição e Outliers",
    fontsize=16,
    fontweight="bold",
    y=1.05,
)

for i, feature in enumerate(features_analise):
    sns.boxplot(
        x="Class",
        y=feature,
        data=df,
        ax=axes[i],
        palette="coolwarm",
        hue="Class",
        legend=False,
    )
    axes[i].set_title(f"Distribuição de {feature}")
    axes[i].set_xlabel("Classe")
    axes[i].set_ylabel(feature)
    axes[i].set_xticklabels(["Normal (0)", "Fraude (1)"])

plt.tight_layout()
plt.show()


# 2: GRÁFICOS DE DENSIDADE (KDE)

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 5))
fig.suptitle(
    "Sugestão 2: Gráficos de Densidade (KDE) - Onde os Dados se Concentram",
    fontsize=16,
    fontweight="bold",
    y=1.05,
)

for i, feature in enumerate(features_analise):
    # Plotando a densidade para transações normais
    sns.kdeplot(
        data=df[df["Class"] == 0],
        x=feature,
        ax=axes[i],
        label="Normal (0)",
        fill=True,
        color="#4C72B0",
        alpha=0.4,
    )
    # Plotando a densidade para fraudes
    sns.kdeplot(
        data=df[df["Class"] == 1],
        x=feature,
        ax=axes[i],
        label="Fraude (1)",
        fill=True,
        color="#C44E52",
        alpha=0.4,
    )

    axes[i].set_title(f"Densidade de {feature}")
    axes[i].set_xlabel(feature)
    axes[i].set_ylabel("Densidade")
    axes[i].legend()

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1616/2949839910.py:31: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(["Normal (0)", "Fraude (1)"])
# /tmp/ipykernel_1616/2949839910.py:31: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(["Normal (0)", "Fraude (1)"])
# /tmp/ipykernel_1616/2949839910.py:31: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(["Normal (0)", "Fraude (1)"])

# %%
import pandas as pd

url = "https://storage.googleapis.com/download.tensorflow.org/data/creditcard.csv"

df = pd.read_csv(url)

df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# **Classificação desbalanceada**

# %%
df["Class"]. value_counts(normalize=True)
# Out:
# Class
# 0    0.998273
# 1    0.001727
# Name: proportion, dtype: float64

# %% [markdown]
# **Variaveis para o modelo**

# %%
import numpy as np
df["Amount_log"] = np.log1p(df["Amount"])

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

df["Amount_scaled"] = scaler.fit_transform(df[["Amount"]])

# %%
from sklearn.model_selection import train_test_split

x = df.drop("Class", axis=1)
y = df["Class"]

x_train, x_test, y_train, y_test = train_test_split(x, y, stratify=y, test_size=0.3, random_state=42)

# %% [markdown]
# **Logica de regressao**

# %%
from os import XATTR_CREATE
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)
model.fit(x_train, y_train)

y_pred = model.predict(x_test)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.84      0.66      0.73       148
#
#     accuracy                           1.00     85443
#    macro avg       0.92      0.83      0.87     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# **Curva ROC**

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

y_probs  = model.predict_proba(x_test)[:,1]

fpr, tpr,_ = roc_curve(y_test, y_probs)

plt.plot(fpr, tpr)
plt.title("ROC curve")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.show()

print("AUC:", roc_auc_score(y_test, y_probs))
# Out:
# AUC: 0.9272042339543365

# %%
from sklearn.metrics import precision_recall_curve

precision, recall, _ = precision_recall_curve(y_test, y_probs)

plt.plot(recall, precision)
plt.title("Precision-recall curve")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.show()

# %% [markdown]
# **Baleaceamento de dados**

# %%
#undersampling

fraudes = df[df["Class"] == 1]
normais = df[df["Class"] == 0].sample(len(fraudes), random_state=42)

df_under = pd.concat([fraudes, normais])

# %%
#oversampling
from imblearn.over_sampling import SMOTE

smote = SMOTE()

x_res, y_res = smote.fit_resample(x, y)

# %%
#conjunto de varias Árvores de decissao
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=50,
                            max_depth=10,
                            class_weight="balanced",
                            n_jobs=-1,
                            random_state=42
                            )
rf.fit(x_train, y_train)
y_pred_rf = rf.predict(x_test)

print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.84      0.76      0.79       148
#
#     accuracy                           1.00     85443
#    macro avg       0.92      0.88      0.90     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
from sklearn.pipeline import Pipeline

pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("model", LogisticRegression(max_iter=1000))
])

pipeline.fit(x_train, y_train)
y_pred = pipeline.predict(x_test)

# %%
#valor de corte ou um ponto crítico definido para separar dois estados, tomar uma decisão ou disparar uma ação
threshold = 0.3

y_pred_custom = (y_probs > threshold).astype(int)

print(classification_report(y_test, y_pred_custom))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.79      0.71      0.75       148
#
#     accuracy                           1.00     85443
#    macro avg       0.89      0.85      0.87     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
#XGBoost constrói árvores de decisão dividindo os dados em grupos. Para decidir onde cortar os dados

from xgboost import XGBClassifier

xgb = XGBClassifier(
    scale_pos_weight=10,
    use_label_encoder=False,
    eval_metric="logloss"
)
xgb.fit(x_train, y_train)

y_pred_xgb = xgb.predict(x_test)
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [18:13:17] WARNING: /__w/xgboost/xgboost/src/learner.cc:793:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
print(classification_report(y_test, y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.94      0.78      0.85       148
#
#     accuracy                           1.00     85443
#    macro avg       0.97      0.89      0.93     85443
# weighted avg       1.00      1.00      1.00     85443
